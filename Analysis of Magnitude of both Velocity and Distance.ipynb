# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
os.chdir('F:\pes documents\cs-5th sem\data analytics\Project\data-analytics-for-star-cluster-simulations')

# %%
df1=pd.read_csv("Dataset\c_0000.csv")
df2=pd.read_csv("Dataset\c_0100.csv")
df3=pd.read_csv("Dataset\c_0200.csv")
df4=pd.read_csv("Dataset\c_0300.csv")
df5=pd.read_csv("Dataset\c_0400.csv")
df6=pd.read_csv("Dataset\c_0500.csv")
df7=pd.read_csv("Dataset\c_0600.csv")
df8=pd.read_csv("Dataset\c_0700.csv")
df9=pd.read_csv("Dataset\c_0800.csv")
df10=pd.read_csv("Dataset\c_0900.csv")
df11=pd.read_csv("Dataset\c_1000.csv")
df12=pd.read_csv("Dataset\c_1100.csv")
df13=pd.read_csv("Dataset\c_1200.csv")
df14=pd.read_csv("Dataset\c_1300.csv")
df15=pd.read_csv("Dataset\c_1400.csv")
df16=pd.read_csv("Dataset\c_1500.csv")
df17=pd.read_csv("Dataset\c_1600.csv")
df18=pd.read_csv("Dataset\c_1700.csv")
df19=pd.read_csv("Dataset\c_1800.csv")

# %%
distance_difference=[]
distance_difference.append([(df1['x'][i]**2+df1['y'][i]**2+df1['z'][i]**2)**0.5 for i in range(len(df1))])
distance_difference.append([(df2['x'][i]**2+df2['y'][i]**2+df2['z'][i]**2)**0.5 for i in range(len(df2))])
distance_difference.append([(df3['x'][i]**2+df3['y'][i]**2+df3['z'][i]**2)**0.5 for i in range(len(df3))])
distance_difference.append([(df4['x'][i]**2+df4['y'][i]**2+df4['z'][i]**2)**0.5 for i in range(len(df4))])
distance_difference.append([(df5['x'][i]**2+df5['y'][i]**2+df5['z'][i]**2)**0.5 for i in range(len(df5))])
distance_difference.append([(df6['x'][i]**2+df6['y'][i]**2+df6['z'][i]**2)**0.5 for i in range(len(df6))])
distance_difference.append([(df7['x'][i]**2+df7['y'][i]**2+df7['z'][i]**2)**0.5 for i in range(len(df7))])
distance_difference.append([(df8['x'][i]**2+df8['y'][i]**2+df8['z'][i]**2)**0.5 for i in range(len(df8))])
distance_difference.append([(df9['x'][i]**2+df9['y'][i]**2+df9['z'][i]**2)**0.5 for i in range(len(df9))])
distance_difference.append([(df10['x'][i]**2+df10['y'][i]**2+df10['z'][i]**2)**0.5 for i in range(len(df10))])
distance_difference.append([(df11['x'][i]**2+df11['y'][i]**2+df11['z'][i]**2)**0.5 for i in range(len(df11))])
distance_difference.append([(df12['x'][i]**2+df12['y'][i]**2+df12['z'][i]**2)**0.5 for i in range(len(df12))])
distance_difference.append([(df13['x'][i]**2+df13['y'][i]**2+df13['z'][i]**2)**0.5 for i in range(len(df13))])
distance_difference.append([(df14['x'][i]**2+df14['y'][i]**2+df14['z'][i]**2)**0.5 for i in range(len(df14))])
distance_difference.append([(df15['x'][i]**2+df15['y'][i]**2+df15['z'][i]**2)**0.5 for i in range(len(df15))])
distance_difference.append([(df16['x'][i]**2+df16['y'][i]**2+df16['z'][i]**2)**0.5 for i in range(len(df16))])
distance_difference.append([(df17['x'][i]**2+df17['y'][i]**2+df17['z'][i]**2)**0.5 for i in range(len(df17))])
distance_difference.append([(df18['x'][i]**2+df18['y'][i]**2+df18['z'][i]**2)**0.5 for i in range(len(df18))])
distance_difference.append([(df19['x'][i]**2+df19['y'][i]**2+df19['z'][i]**2)**0.5 for i in range(len(df19))])

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.boxplot(distance_difference,vert=False)
ax.set_title('Distance of the stars from the center')
ax.set_xlabel('Distance from the origin')
ax.set_ylabel('Distribution of stars at different time')

plt.show()
fig=plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
fig2=plt.figure(figsize=(10,10))
ax5 = fig2.add_subplot(221)
ax6 = fig2.add_subplot(222)
ax7 = fig2.add_subplot(223)
ax8 = fig2.add_subplot(224)
fig3=plt.figure(figsize=(10,10))
ax9 = fig3.add_subplot(221)
ax10 = fig3.add_subplot(222)
ax11 = fig3.add_subplot(223)
ax12 = fig3.add_subplot(224)
fig4=plt.figure(figsize=(10,10))

ax13 = fig4.add_subplot(221)
ax14 = fig4.add_subplot(222)
ax15 = fig4.add_subplot(223)
ax16 = fig4.add_subplot(224)
fig5=plt.figure(figsize=(10,10))
ax17 = fig5.add_subplot(221)
ax18 = fig5.add_subplot(222)
ax19 = fig5.add_subplot(223)

ax1.hist(distance_difference[0],bins=30)
ax2.hist(distance_difference[1],bins=30)
ax3.hist(distance_difference[2],bins=30)
ax4.hist(distance_difference[3],bins=30)
ax5.hist(distance_difference[4],bins=30)
ax6.hist(distance_difference[5],bins=30)
ax7.hist(distance_difference[6],bins=30)
ax8.hist(distance_difference[7],bins=30)
ax9.hist(distance_difference[8],bins=30)
ax10.hist(distance_difference[9],bins=30)
ax11.hist(distance_difference[10],bins=30)
ax12.hist(distance_difference[11],bins=30)
ax13.hist(distance_difference[12],bins=30)
ax14.hist(distance_difference[13],bins=30)
ax15.hist(distance_difference[14],bins=30)
ax16.hist(distance_difference[15],bins=30)
ax17.hist(distance_difference[16],bins=30)
ax18.hist(distance_difference[17],bins=30)
ax19.hist(distance_difference[18],bins=30)
ax1.set_title('Time 1')
ax1.set_ylabel('Number of Stars')
ax1.set_xlabel('Distance from origin')

ax2.set_title('Time 2')
ax2.set_xlabel('Distance from origin')

ax3.set_title('Time 3')
ax3.set_ylabel('Number of Stars')
ax3.set_xlabel('Distance from origin')

ax4.set_title('Time 4')
ax4.set_xlabel('Distance from origin')

ax5.set_title('Time 5')
ax5.set_ylabel('Number of Stars')
ax5.set_xlabel('Distance from origin')

ax6.set_title('Time 6')
ax6.set_xlabel('Distance from origin')

ax7.set_title('Time 7')
ax7.set_ylabel('Number of Stars')
ax7.set_xlabel('Distance from origin')

ax8.set_title('Time 8')
ax8.set_xlabel('Distance from origin')

ax9.set_title('Time 9')
ax9.set_ylabel('Number of Stars')
ax9.set_xlabel('Distance from origin')

ax10.set_title('Time 10')
ax10.set_xlabel('Distance from origin')

ax11.set_title('Time 11')
ax11.set_ylabel('Number of Stars')
ax11.set_xlabel('Distance from origin')

ax12.set_title('Time 12')
ax12.set_xlabel('Distance from origin')

ax13.set_title('Time 13')
ax13.set_ylabel('Number of Stars')
ax13.set_xlabel('Distance from origin')

ax14.set_title('Time 14')
ax14.set_xlabel('Distance from origin')

ax15.set_title('Time 15')
ax15.set_ylabel('Number of Stars')
ax15.set_xlabel('Distance from origin')

ax16.set_title('Time 16')
ax16.set_xlabel('Distance from origin')

ax17.set_title('Time 17')
ax17.set_ylabel('Number of Stars')
ax17.set_xlabel('Distance from origin')

ax18.set_title('Time 18')
ax18.set_xlabel('Distance from origin')

ax19.set_title('Time 19')
ax19.set_ylabel('Number of Stars')
ax19.set_xlabel('Distance from origin')


plt.show()

# %%
velocity_difference=[]
velocity_difference.append([(df1['vx'][i]**2+df1['vy'][i]**2+df1['vz'][i]**2)**0.5 for i in range(len(df1))])
velocity_difference.append([(df2['vx'][i]**2+df2['vy'][i]**2+df2['vz'][i]**2)**0.5 for i in range(len(df2))])
velocity_difference.append([(df3['vx'][i]**2+df3['vy'][i]**2+df3['vz'][i]**2)**0.5 for i in range(len(df3))])
velocity_difference.append([(df4['vx'][i]**2+df4['vy'][i]**2+df4['vz'][i]**2)**0.5 for i in range(len(df4))])
velocity_difference.append([(df5['vx'][i]**2+df5['vy'][i]**2+df5['vz'][i]**2)**0.5 for i in range(len(df5))])
velocity_difference.append([(df6['vx'][i]**2+df6['vy'][i]**2+df6['vz'][i]**2)**0.5 for i in range(len(df6))])
velocity_difference.append([(df7['vx'][i]**2+df7['vy'][i]**2+df7['vz'][i]**2)**0.5 for i in range(len(df7))])
velocity_difference.append([(df8['vx'][i]**2+df8['vy'][i]**2+df8['vz'][i]**2)**0.5 for i in range(len(df8))])
velocity_difference.append([(df9['vx'][i]**2+df9['vy'][i]**2+df9['vz'][i]**2)**0.5 for i in range(len(df9))])
velocity_difference.append([(df10['vx'][i]**2+df10['vy'][i]**2+df10['vz'][i]**2)**0.5 for i in range(len(df10))])
velocity_difference.append([(df11['vx'][i]**2+df11['vy'][i]**2+df11['vz'][i]**2)**0.5 for i in range(len(df11))])
velocity_difference.append([(df12['vx'][i]**2+df12['vy'][i]**2+df12['vz'][i]**2)**0.5 for i in range(len(df12))])
velocity_difference.append([(df13['vx'][i]**2+df13['vy'][i]**2+df13['vz'][i]**2)**0.5 for i in range(len(df13))])
velocity_difference.append([(df14['vx'][i]**2+df14['vy'][i]**2+df14['vz'][i]**2)**0.5 for i in range(len(df14))])
velocity_difference.append([(df15['vx'][i]**2+df15['vy'][i]**2+df15['vz'][i]**2)**0.5 for i in range(len(df15))])
velocity_difference.append([(df16['vx'][i]**2+df16['vy'][i]**2+df16['vz'][i]**2)**0.5 for i in range(len(df16))])
velocity_difference.append([(df17['vx'][i]**2+df17['vy'][i]**2+df17['vz'][i]**2)**0.5 for i in range(len(df17))])
velocity_difference.append([(df18['vx'][i]**2+df18['vy'][i]**2+df18['vz'][i]**2)**0.5 for i in range(len(df18))])
velocity_difference.append([(df19['vx'][i]**2+df19['vy'][i]**2+df19['vz'][i]**2)**0.5 for i in range(len(df19))])

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.boxplot(velocity_difference,vert=False)
ax.set_title('Velocity of the stars from the center')
ax.set_xlabel('Velocity')
ax.set_ylabel('Distribution of stars at different times')

plt.show()
fig=plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
fig2=plt.figure(figsize=(10,10))
ax5 = fig2.add_subplot(221)
ax6 = fig2.add_subplot(222)
ax7 = fig2.add_subplot(223)
ax8 = fig2.add_subplot(224)
fig3=plt.figure(figsize=(10,10))
ax9 = fig3.add_subplot(221)
ax10 = fig3.add_subplot(222)
ax11 = fig3.add_subplot(223)
ax12 = fig3.add_subplot(224)
fig4=plt.figure(figsize=(10,10))
ax13 = fig4.add_subplot(221)
ax14 = fig4.add_subplot(222)
ax15 = fig4.add_subplot(223)
ax16 = fig4.add_subplot(224)
fig5=plt.figure(figsize=(10,10))
ax17 = fig5.add_subplot(221)
ax18 = fig5.add_subplot(222)
ax19 = fig5.add_subplot(223)

ax1.hist(velocity_difference[0],bins=30)
ax2.hist(velocity_difference[1],bins=30)
ax3.hist(velocity_difference[2],bins=30)
ax4.hist(velocity_difference[3],bins=30)
ax5.hist(velocity_difference[4],bins=30)
ax6.hist(velocity_difference[5],bins=30)
ax7.hist(velocity_difference[6],bins=30)
ax8.hist(velocity_difference[7],bins=30)
ax9.hist(velocity_difference[8],bins=30)
ax10.hist(velocity_difference[9],bins=30)
ax11.hist(velocity_difference[10],bins=30)
ax12.hist(velocity_difference[11],bins=30)
ax13.hist(velocity_difference[12],bins=30)
ax14.hist(velocity_difference[13],bins=30)
ax15.hist(velocity_difference[14],bins=30)
ax16.hist(velocity_difference[15],bins=30)
ax17.hist(velocity_difference[16],bins=30)
ax18.hist(velocity_difference[17],bins=30)
ax19.hist(velocity_difference[18],bins=30)
ax1.set_title('Time 1')
ax1.set_ylabel('Number of Stars')
ax1.set_xlabel('Velocity')

ax2.set_title('Time 2')
ax2.set_xlabel('Velocity')

ax3.set_title('Time 3')
ax3.set_ylabel('Number of Stars')
ax3.set_xlabel('Velocity')

ax4.set_title('Time 4')
ax4.set_xlabel('Velocity')

ax5.set_title('Time 5')
ax5.set_ylabel('Number of Stars')
ax5.set_xlabel('Velocity')

ax6.set_title('Time 6')
ax6.set_xlabel('Velocity')

ax7.set_title('Time 7')
ax7.set_ylabel('Number of Stars')
ax7.set_xlabel('Velocity')

ax8.set_title('Time 8')
ax8.set_xlabel('Velocity')

ax9.set_title('Time 9')
ax9.set_ylabel('Number of Stars')
ax9.set_xlabel('Velocity')

ax10.set_title('Time 10')
ax10.set_xlabel('Velocity')

ax11.set_title('Time 11')
ax11.set_ylabel('Number of Stars')
ax11.set_xlabel('Velocity')

ax12.set_title('Time 12')
ax12.set_xlabel('Velocity')

ax13.set_title('Time 13')
ax13.set_ylabel('Number of Stars')
ax13.set_xlabel('Velocity')

ax14.set_title('Time 14')
ax14.set_xlabel('Velocity')

ax15.set_title('Time 15')
ax15.set_ylabel('Number of Stars')
ax15.set_xlabel('Velocity')

ax16.set_title('Time 16')
ax16.set_xlabel('Velocity')

ax17.set_title('Time 17')
ax17.set_ylabel('Number of Stars')
ax17.set_xlabel('Velocity')

ax18.set_title('Time 18')
ax18.set_xlabel('Velocity')

ax19.set_title('Time 19')
ax19.set_ylabel('Number of Stars')
ax19.set_xlabel('Velocity')


plt.show()

# %% [markdown]
# ### From the above graphs, it is clear that the average magnitude of the velocity of the stars do not change at different time

# %%
for i in range(19):
    plt.scatter(velocity_difference[i],distance_difference[i])
    plt.title('Distance magnitude vs Velocity magnitude at time: '+str(i+1))
    plt.xlabel('Velocity')
    plt.ylabel('Distance')
    plt.show()
