# %%
import os
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVR
import pandas as pd
import numpy as np
from sklearn import svm
import math
import copy
os.chdir('/home/ninaad/cs-5thsem/data-analytics-for-star-cluster-simulations')
df1=pd.read_csv("Dataset/c_0000.csv")
df2=pd.read_csv("Dataset/c_0100.csv")
df3=pd.read_csv("Dataset/c_0200.csv")
df4=pd.read_csv("Dataset/c_0300.csv")
df5=pd.read_csv("Dataset/c_0400.csv")
df6=pd.read_csv("Dataset/c_0500.csv")
df7=pd.read_csv("Dataset/c_0600.csv")
df8=pd.read_csv("Dataset/c_0700.csv")
df9=pd.read_csv("Dataset/c_0800.csv")
df10=pd.read_csv("Dataset/c_0900.csv")
df11=pd.read_csv("Dataset/c_1000.csv")
df12=pd.read_csv("Dataset/c_1100.csv")
df13=pd.read_csv("Dataset/c_1200.csv")
df14=pd.read_csv("Dataset/c_1300.csv")
df15=pd.read_csv("Dataset/c_1400.csv")
df16=pd.read_csv("Dataset/c_1500.csv")
df17=pd.read_csv("Dataset/c_1600.csv")
df18=pd.read_csv("Dataset/c_1700.csv")
df19=pd.read_csv("Dataset/c_1800.csv")

df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19]

df_all = pd.DataFrame()

k=0
for i in df_list:
    i['time'] = k
    df_all = df_all.append(i)
    k+=1


df_all1 = copy.deepcopy(df_all)
df_all2 = copy.deepcopy(df_all)


df_all1['position'] = df_all1.apply(lambda row: math.sqrt(math.pow(row.x,2) + math.pow(row.y,2) + math.pow(row.z,2)), axis=1)
df_all2['velocity'] = df_all2.apply(lambda row: math.sqrt(math.pow(row.vx,2) + math.pow(row.vy,2) + math.pow(row.vz,2)), axis=1)




df_all_p2 = copy.deepcopy(df_all)

df_all_p2['x'] = df_all_p2.apply(lambda row: math.pow(row.x,2) , axis=1)
df_all_p2['y'] = df_all_p2.apply(lambda row: math.pow(row.y,2) , axis=1)
df_all_p2['z'] = df_all_p2.apply(lambda row: math.pow(row.z,2) , axis=1)


df_all_v2 = copy.deepcopy(df_all)

df_all_v2['vx'] = df_all_v2.apply(lambda row: math.pow(row.vx,2) , axis=1)
df_all_v2['vy'] = df_all_v2.apply(lambda row: math.pow(row.vy,2) , axis=1)
df_all_v2['vz'] = df_all_v2.apply(lambda row: math.pow(row.vz,2) , axis=1)



print(df_all)
print("Next\n")
print(df_all1)


print("Next\n")
print(df_all2)
# Out:
#               x         y         z        vx        vy        vz         m  \
# 0      0.485939 -0.524359 -0.531982  0.461539 -0.033776 -0.322765  0.000016
# 1     -0.065961  0.080844 -0.276031 -0.575780  1.107815 -0.293408  0.000016
# 2     -0.034809  0.076795 -0.390880 -0.553991 -0.173861  0.059251  0.000016
# 3      1.502104  1.442983  1.449747 -0.090266  0.326612 -0.310594  0.000016
# 4     -0.009554  0.538341 -0.267264  0.011855 -0.011874 -0.405565  0.000016
# 5     -0.356017 -0.045705  0.335006 -0.709008 -0.649903  0.397949  0.000016
# 6     -0.397190 -1.401627 -0.757772  0.041345  0.718185  0.422623  0.000016
# 7     -0.916657  0.643472 -0.146350 -0.511860  0.220190 -0.529937  0.000016
# 8      2.241766  0.790756  0.290989  0.292099  0.053339 -0.472290  0.000016
# 9     -0.976209  0.445163 -0.705493 -0.120242 -0.231255 -0.227857  0.000016
# 10     0.333829 -0.027976 -0.049035 -0.404203  0.422303 -0.475672  0.000016
# ...

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.tree import DecisionTreeRegressor

from sklearn.multioutput import MultiOutputRegressor
# Out:
# /home/ninaad/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
print(len(df_train))
print(len(df_test))
# Out:
# 1151744
# 63970

# %%
offset = len(df19.index)
total_len = len(df_all)

df_train = df_all2[:total_len-offset]
df_test = df_all2[total_len-offset:]


X_train = df_train[['vx','vy','vz','velocity']]
X_test = df_test[['vx','vy','vz','velocity']]

y_train = df_train[['x','y','z']]
y_test = df_test[['x','y','z']]


print("The results are the RMSE values")
print("Considering magnitude of velocity in addition to velocity vectors to predict position vectors")

a = LinearRegression().fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5

print("Linear Regression :"+str(RMSE))



b = KNeighborsRegressor(n_neighbors=200).fit(X_train, y_train)                  
predict_test = b.predict(X_test)   
RMSE = (mean_squared_error(y_test, b.predict(X_test)))**0.5

print("KNeighborsRegressor :"+str(RMSE))







print("\n")



# print(df_train[['vx','vy']])
X_train = df_train[['vx','vy','vz']]
X_test = df_test[['vx','vy','vz']]

y_train = df_train[['x','y','z']]
y_test = df_test[['x','y','z']]


print("Considering only velocity vectors to predict position vectors")

a = LinearRegression().fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5


print("Linear Regression :"+str(RMSE))


KNeighborsRegressor()

a = KNeighborsRegressor(n_neighbors=200).fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5



print("KNeighborsRegressor :"+str(RMSE))




print("\n")






offset = len(df19.index)
total_len = len(df_all)

df_train = df_all2[:total_len-offset]
df_test = df_all2[total_len-offset:]

print("Considering only position vectors to predict velocity vectors")

X_train = df_train[['x','y','z']]
X_test = df_test[['x','y','z']]

y_train = df_train[['vx','vy','vz']]
y_test = df_test[['vx','vy','vz']]



a = LinearRegression().fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5

print("Linear Regression :"+str(RMSE))


KNeighborsRegressor()


a = KNeighborsRegressor(n_neighbors=200).fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5

print("KNeighborsRegressor :"+str(RMSE))


print("\n")


offset = len(df19.index)
total_len = len(df_all)

df_train = df_all1[:total_len-offset]
df_test = df_all1[total_len-offset:]

print("Considering position vectors and position magnitude to predict velocity vectors")

X_train = df_train[['x','y','z','position']]
X_test = df_test[['x','y','z','position']]

y_train = df_train[['vx','vy','vz']]
y_test = df_test[['vx','vy','vz']]



a = LinearRegression().fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5

print("Linear Regression :"+str(RMSE))


KNeighborsRegressor()


a = KNeighborsRegressor(n_neighbors=200).fit(X_train, y_train)                  
predict_test = a.predict(X_test)   
RMSE = (mean_squared_error(y_test, a.predict(X_test)))**0.5

print("KNeighborsRegressor :"+str(RMSE))


print("\n")
# Out:
# The results are the RMSE values
# Considering magnitude of velocity in addition to velocity vectors to predict position vectors
# Linear Regression :1.1412059155246128
# KNeighborsRegressor :1.1440114470573572
#
#
# Considering only velocity vectors to predict position vectors
# Linear Regression :1.1412017234021627
# KNeighborsRegressor :1.1436454731971437
#
#
# Considering only position vectors to predict velocity vectors
# Linear Regression :0.40814847129374016
# KNeighborsRegressor :0.40907726269010375
#
#
# Considering position vectors and position magnitude to predict velocity vectors
# Linear Regression :0.40814895849350197
# KNeighborsRegressor :0.4090971448307957

# %% [markdown]
# # Analysis
# ## Linear regression was chosen as the correlations of all the variables were 0. From the earlier histogram, it can be seen that there are no outliers.
# ## K Nearest Neighbours Regression was used as it is expected that planets closer to each other would behave similarly. A k value of 200 was taken as it provided a good balance.
# ## There was no signoficant RMSE change when magnitudes were added in the input.

# %%
df_norm = df_all[['x', 'y', 'z', 'vx','vy','vz']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
X = X_train.values[:,:3]
# print(X)

y = y_train.values[:,:3]
# print(y)


num_inputs = len(X[0])
hidden_layer_neurons = 5
np.random.seed(4)
w1 = 2*np.random.random((num_inputs, hidden_layer_neurons)) - 1
# print(w1)


num_outputs = len(y[0])
w2 = 2*np.random.random((hidden_layer_neurons, num_outputs)) - 1
# print(w2)

# %%
learning_rate = 0.2 # slowly update the network
for epoch in range(30):
    l1 = 1/(1 + np.exp(-(np.dot(X, w1)))) # sigmoid function
    l2 = 1/(1 + np.exp(-(np.dot(l1, w2))))
    er = (abs(y - l2)).mean()
    l2_delta = (y - l2)*(l2 * (1-l2))
    l1_delta = l2_delta.dot(w2.T) * (l1 * (1-l1))
    w2 += l1.T.dot(l2_delta) * learning_rate
    w1 += X.T.dot(l1_delta) * learning_rate
print('Error:', er)

# %% [markdown]
# # ANN
# # A model was trained to predict the velocities based on the positions, but for epochs from 4 to 30, the error remained the same. This could possibly be due to overfitting. Higher epochs were not tried as the time to train was too much.
